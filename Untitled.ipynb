# %%
#Martin Work

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
runs=pd.read_csv("runs.csv")
race=pd.read_csv("races.csv")
canada=pd.read_csv("woodbine_horses.csv")

# %%
race.head()
# Out:
#    race_id        date venue  race_no config  surface  distance         going  \
# 0        0  1997-06-02    ST        1      A        0      1400  GOOD TO FIRM
# 1        1  1997-06-02    ST        2      A        0      1200  GOOD TO FIRM
# 2        2  1997-06-02    ST        3      A        0      1400  GOOD TO FIRM
# 3        3  1997-06-02    ST        4      A        0      1200  GOOD TO FIRM
# 4        4  1997-06-02    ST        5      A        0      1600  GOOD TO FIRM
#
#   horse_ratings      prize  ...  place_combination3  place_combination4  \
# 0         40-15   485000.0  ...                 6.0                 NaN
# 1         40-15   485000.0  ...                 4.0                 NaN
# 2         60-40   625000.0  ...                13.0                 NaN
# 3        120-95  1750000.0  ...                10.0                 NaN
# 4         60-40   625000.0  ...                 1.0                 NaN
#
#    place_dividend1  place_dividend2  place_dividend3  place_dividend4  \
# 0             36.5             25.5             18.0              NaN
# 1             12.5             47.0             33.5              NaN
# 2             23.0             23.0             59.5              NaN
# 3             14.0             24.5             16.0              NaN
# 4             15.5             28.0             17.5              NaN
#
#    win_combination1  win_dividend1  win_combination2  win_dividend2
# 0                 8          121.0               NaN            NaN
# 1                 5           23.5               NaN            NaN
# 2                11           70.0               NaN            NaN
# 3                 5           52.0               NaN            NaN
# 4                 2           36.5               NaN            NaN
#
# [5 rows x 37 columns]

# %%
del race["place_combination3"],race["place_combination4"],race["place_dividend1"],race["place_dividend2"],race["place_dividend3"],race["place_dividend4"],race["win_combination1"],race["win_dividend1"],race["win_combination2"],race["win_dividend2"],race["sec_time7"],race["time1"],race["time2"],race["time3"],race["time4"],race["time5"],race["time6"],race["time7"],race["place_combination1"],race["place_combination2"],race["sec_time1"],race["sec_time2"],race["sec_time3"],race["sec_time4"],race["sec_time5"],race["sec_time6"],

# %%
race.head()
# Out:
#    race_id        date venue  race_no config  surface  distance         going  \
# 0        0  1997-06-02    ST        1      A        0      1400  GOOD TO FIRM
# 1        1  1997-06-02    ST        2      A        0      1200  GOOD TO FIRM
# 2        2  1997-06-02    ST        3      A        0      1400  GOOD TO FIRM
# 3        3  1997-06-02    ST        4      A        0      1200  GOOD TO FIRM
# 4        4  1997-06-02    ST        5      A        0      1600  GOOD TO FIRM
#
#   horse_ratings      prize  race_class
# 0         40-15   485000.0           5
# 1         40-15   485000.0           5
# 2         60-40   625000.0           4
# 3        120-95  1750000.0           1
# 4         60-40   625000.0           4

# %%
raceruns=pd.merge(runs,race,how="outer")
raceruns.head()
# Out:
#    race_id  horse_no  horse_id  result  won  lengths_behind  horse_age  \
# 0        0       1.0    3917.0    10.0  0.0            8.00        3.0
# 1        0       2.0    2157.0     8.0  0.0            5.75        3.0
# 2        0       3.0     858.0     7.0  0.0            4.75        3.0
# 3        0       4.0    1853.0     9.0  0.0            6.25        3.0
# 4        0       5.0    2796.0     6.0  0.0            3.75        3.0
#
#   horse_country horse_type  horse_rating  ...        date  venue  race_no  \
# 0           AUS    Gelding          60.0  ...  1997-06-02     ST        1
# 1            NZ    Gelding          60.0  ...  1997-06-02     ST        1
# 2            NZ    Gelding          60.0  ...  1997-06-02     ST        1
# 3           SAF    Gelding          60.0  ...  1997-06-02     ST        1
# 4            GB    Gelding          60.0  ...  1997-06-02     ST        1
#
#    config  surface  distance         going  horse_ratings     prize  \
# 0       A        0      1400  GOOD TO FIRM          40-15  485000.0
# 1       A        0      1400  GOOD TO FIRM          40-15  485000.0
# 2       A        0      1400  GOOD TO FIRM          40-15  485000.0
# 3       A        0      1400  GOOD TO FIRM          40-15  485000.0
# 4       A        0      1400  GOOD TO FIRM          40-15  485000.0
#
#    race_class
# 0           5
# 1           5
# 2           5
# 3           5
# 4           5
#
# [5 rows x 47 columns]

# %%
country=pd.DataFrame(raceruns.groupby("horse_country")["won"].mean()).sort_values(by="won",ascending=False)

# %%
country.plot.bar()
plt.show()

# %%
hor=raceruns.drop_duplicates("horse_id")
country=pd.DataFrame(hor.groupby("horse_country")["horse_id"].count())
country=country.sort_values(by="horse_id",ascending=False)
BarPandas=country.plot.bar()

# %%
P=pd.DataFrame(raceruns.groupby('actual_weight')['won'].mean())
P.plot.bar()

# %%
distance=pd.DataFrame(raceruns.groupby(["distance"])["distance"].count())
distance=distance.rename(columns={"distance":"Count"})
distance=distance.sort_values(by="Count",ascending=False)
distance
# Out:
#           Count
# distance
# 2200        909
# 2400        200

# %%
pd.DataFrame(race.groupby(["config","distance"])["distance"].count())
# Out:
#                  distance
# config distance
# A      1000           135
#        1200           896
#        1400           224
#        1600           161
#        1650           518
#        1800           202
#        2000            45
#        2200            13
#        2400            15
# A+3    1000            50
#        1200           152
#        1400           163
#        1600           112
#        1800            48
#        2000            33
#        2400             5
# B      1000           112
#        1200           272
#        1400            51
#        1600            25
#        1650           242
#        1800            82
#        2000            10
#        2200            23
#        2400             2
# B+2    1000            30
#        1200           186
#        1400           185
#        1600           129
#        1800            38
#        2000            29
#        2200             1
#        2400             2
# C      1000           172
#        1200           319
#        1400           206
#        1600           113
#        1650           213
#        1800           122
#        2200            28
#        2400             1
# C+3    1000           199
#        1200           192
#        1400           252
#        1600            97
#        1650           122
#        1800            97
#        2200            25

# %%
gelding=runs.query("horse_type=='Gelding'")
mare=runs.query("horse_type=='Mare'")
horse=runs.query("horse_type=='Horse'")
brown=runs.query("horse_type=='Brown'")
rig=runs.query("horse_type=='rig'")
colt=runs.query("horse_type=='Colt'")
roan=runs.query("horse_type=='Roan'")

# %%
pd.DataFrame(gelding.groupby(["horse_country","horse_age"])["actual_weight"].mean())
# Out:
#                          actual_weight
# horse_country horse_age
# ARG           3             123.060870
#               4             118.000000
#               5             121.000000
# AUS           2             122.569163
#               3             122.646487
# ...                                ...
# USA           5             123.962733
#               6             122.284091
#               7             120.403226
#               8             118.000000
# ZIM           3             121.750000
#
# [69 rows x 1 columns]

# %%
import scipy.stats as sts
plt.hist(runs["declared_weight"])
plt.xlabel('Declared Weight (lbs)')
plt.ylabel('Counts')
plt.show()
print(sts.normaltest(runs["declared_weight"]))
var=np.var(runs["declared_weight"])
std=np.std(runs["declared_weight"])
mean=np.mean(runs["declared_weight"])
median=np.median(runs["declared_weight"])
mode=sts.mode(runs["declared_weight"])
print(f"The variance is: {var}")
# Out:
# NormaltestResult(statistic=591.4050582445592, pvalue=3.7846290392127055e-129)
# The variance is: 3887.1738817240785

# %%
bins=[1]
result=pd.DataFrame(runs.groupby("actual_weight")["result"].)

# %%
PAA=pd.DataFrame(pd.cut(purchase_data["Age"],bins=[0,9,14,19,24,29,34,39,100],labels=["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]).value_counts())
PAA=PAA.rename(columns={
    "Age":"Purchase Count"
})
purchase=purchase_data.drop_duplicates("SN")
PAB=pd.DataFrame(pd.cut(purchase["Age"],bins=[0,9,14,19,24,29,34,39,100],labels=["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"]).value_counts())
PAA=PAA.sort_index()
PAA['Average Purchase Price']=purchase_data.groupby(pd.cut(purchase_data["Age"],bins=[0,9,14,19,24,29,34,39,100],labels=["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"])).agg({'Price':'mean'})
PAA['Total Purchase Value']=purchase_data.groupby(pd.cut(purchase_data["Age"],bins=[0,9,14,19,24,29,34,39,100],labels=["<10","10-14","15-19","20-24","25-29","30-34","35-39","40+"])).agg({'Price':'sum'})
PAA['Avg Total Purchase per Person']=PAA["Total Purchase Value"].divide(PAB["Age"])

# %%
runs["declared_weight"].max()

# %%
pd.DataFrame(runs.groupby('actual_weight')['actual_weight'].count())

# %%
#Jorge work

# %%
#Mario work

# %%
#Sergio work
