# %%
#Martin Work

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
runs=pd.read_csv("runs.csv")
race=pd.read_csv("races.csv")

# %%
racecount=pd.DataFrame(runs.groupby("horse_id")["race_id"].count())
hor=runs.drop_duplicates("horse_id")
country=pd.DataFrame(hor.groupby("horse_country")["horse_id"].count())
country=country.sort_values(by="horse_id",ascending=False)
BarPandas=country.plot.bar()

# %%
runs["horse_country"].unique()

# %%
#Jorge work

# %%
# Checking if weight has something ot do with winning
weight = runs.groupby("actual_weight")["won"].mean()
weight.plot.bar()

# %%
# horse and country
from matplotlib.pyplot import figure
figure(figsize=(15,4))
country = runs.groupby("horse_country")["won"].value_counts() 

country.plot(kind="bar")
plt.show()

# %%
# horse type and country
figure(figsize=(15,4))
country = runs.groupby("horse_country")["horse_type"].value_counts()
country.plot(kind="bar")
plt.show()

# %%
# horse type and country
figure(figsize=(15,4))
country = runs.groupby("horse_country")["horse_age"].value_counts()
country.plot(kind="bar")
plt.show()

# %%
data = runs[runs["won"]==1]

data_id = data["horse_id"]

data_cou = data["horse_country"]
data_wei = data["actual_weight"]
data_typ = data["horse_type"]
data_age = data["horse_age"]

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 8))
ax = plt.axes(projection='3d')
ax.scatter3D(data_age, data_wei, data_id, cmap='Greens');

ax.set_xlabel('age')
ax.set_ylabel('actual weight')
ax.set_zlabel('id')
plt.show()

# %%
#Mario work

# %%
#Sergio work
