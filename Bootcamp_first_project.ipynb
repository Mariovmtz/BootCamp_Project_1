# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
races_df=pd.read_csv("Data/races.csv")
races_df.head()
# Out:
#    race_id        date venue  race_no config  surface  distance         going  \
# 0        0  1997-06-02    ST        1      A        0      1400  GOOD TO FIRM
# 1        1  1997-06-02    ST        2      A        0      1200  GOOD TO FIRM
# 2        2  1997-06-02    ST        3      A        0      1400  GOOD TO FIRM
# 3        3  1997-06-02    ST        4      A        0      1200  GOOD TO FIRM
# 4        4  1997-06-02    ST        5      A        0      1600  GOOD TO FIRM
#
#   horse_ratings      prize  ...  place_combination3  place_combination4  \
# 0         40-15   485000.0  ...                 6.0                 NaN
# 1         40-15   485000.0  ...                 4.0                 NaN
# 2         60-40   625000.0  ...                13.0                 NaN
# 3        120-95  1750000.0  ...                10.0                 NaN
# 4         60-40   625000.0  ...                 1.0                 NaN
#
# ...

# %%
runs_df=pd.read_csv("Data/runs.csv")
runs_df.head()
# Out:
#    race_id  horse_no  horse_id  result  won  lengths_behind  horse_age  \
# 0        0         1      3917      10  0.0            8.00          3
# 1        0         2      2157       8  0.0            5.75          3
# 2        0         3       858       7  0.0            4.75          3
# 3        0         4      1853       9  0.0            6.25          3
# 4        0         5      2796       6  0.0            3.75          3
#
#   horse_country horse_type  horse_rating  ...  time2  time3  time4  time5  \
# 0           AUS    Gelding            60  ...  21.59  23.86  24.62    NaN
# 1            NZ    Gelding            60  ...  21.99  23.30  23.70    NaN
# 2            NZ    Gelding            60  ...  21.59  23.90  24.22    NaN
# 3           SAF    Gelding            60  ...  21.83  23.70  24.00    NaN
# 4            GB    Gelding            60  ...  21.75  23.22  23.50    NaN
#
#    time6  finish_time  win_odds  place_odds  trainer_id  jockey_id
# ...

# %%
horse_df = pd.read_csv("Data/race-result-horse.csv")
horse_df = horse_df[["finishing_position","horse_name","jockey","trainer","actual_weight","declared_horse_weight","finish_time","race_id"]]
horse_df.head()
# Out:
#   finishing_position         horse_name     jockey       trainer  \
# 0                  1      DOUBLE DRAGON  B Prebble        D Cruz
# 1                  2  PLAIN BLUE BANNER    D Whyte  D E Ferraris
# 2                  3         GOLDWEAVER  Y T Cheng      Y S Tsui
# 3                  4     SUPREME PROFIT  J Moreira      C S Shum
# 4                  5       THE ONLY KID   Z Purton       K W Lui
#
#   actual_weight declared_horse_weight finish_time   race_id
# 0           133                  1032     1.22.33  2014-001
# 1           133                  1075     1.22.65  2014-001
# 2           121                  1065     1.22.66  2014-001
# 3           132                  1222     1.22.66  2014-001
# 4           125                  1136     1.23.02  2014-001

# %%
race_df= pd.read_csv("Data/race-result-race.csv")
race_df=race_df[["race_id","race_class","race_distance"]]
race_df.head()
# Out:
#     race_id race_class  race_distance
# 0  2014-001    Class 5           1400
# 1  2014-010    Class 2           1400
# 2  2014-002    Class 5           1200
# 3  2014-003    Class 1           1200
# 4  2014-004    Class 4           1200

# %%
merge_df=pd.merge(race_df,horse_df,on="race_id",how="outer")
merge_df.head()
# Out:
#     race_id race_class  race_distance finishing_position         horse_name  \
# 0  2014-001    Class 5           1400                  1      DOUBLE DRAGON
# 1  2014-001    Class 5           1400                  2  PLAIN BLUE BANNER
# 2  2014-001    Class 5           1400                  3         GOLDWEAVER
# 3  2014-001    Class 5           1400                  4     SUPREME PROFIT
# 4  2014-001    Class 5           1400                  5       THE ONLY KID
#
#       jockey       trainer actual_weight declared_horse_weight finish_time
# 0  B Prebble        D Cruz           133                  1032     1.22.33
# 1    D Whyte  D E Ferraris           133                  1075     1.22.65
# 2  Y T Cheng      Y S Tsui           121                  1065     1.22.66
# 3  J Moreira      C S Shum           132                  1222     1.22.66
# 4   Z Purton       K W Lui           125                  1136     1.23.02

# %%
merge_df["finishing_position"].value_counts()
# Out:
# 1        2361
# 2        2354
# 3        2350
# 6        2346
# 5        2341
# 4        2340
# 7        2339
# 8        2329
# 9        2305
# 10       2260
# 11       2186
# 12       2020
# 13        995
# 14        838
# WV        461
# WV-A      102
# 4 DH       35
# PU         29
# UR         26
# 3 DH       20
# 5 DH       18
# WX         16
# 2 DH       14
# 6 DH       14
# 1 DH       12
# 8 DH       12
# FE         10
# WX-A       10
# 10 DH       8
# 7 DH        8
# 9 DH        8
# DNF         7
# TNP         6
# 11 DH       4
# 12 DH       2
# DISQ        1
# Name: finishing_position, dtype: int64

# %%
merge_df=merge_df.loc[(merge_df["finishing_position"] != "WV")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "WV-A")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "4 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "PU")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "UR")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "3 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "5 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "WX")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "2 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "6 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "8 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "1 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "WX-A")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "FE")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "10 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "9 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "7 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "11 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "12 DH")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "DNF")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "TNP")]
merge_df=merge_df.loc[(merge_df["finishing_position"] != "DISQ")]
merge_df
# Out:
#         race_id race_class  race_distance finishing_position  \
# 0      2014-001    Class 5           1400                  1
# 1      2014-001    Class 5           1400                  2
# 2      2014-001    Class 5           1400                  3
# 3      2014-001    Class 5           1400                  4
# 4      2014-001    Class 5           1400                  5
# ...         ...        ...            ...                ...
# 30182  2016-805    Class 3           1400                  9
# 30183  2016-805    Class 3           1400                 10
# 30184  2016-805    Class 3           1400                 11
# 30185  2016-805    Class 3           1400                 12
# 30186  2016-805    Class 3           1400                 13
#
#               horse_name     jockey       trainer actual_weight  \
# 0          DOUBLE DRAGON  B Prebble        D Cruz           133
# 1      PLAIN BLUE BANNER    D Whyte  D E Ferraris           133
# ...

# %%
merge_df["finishing_position"].value_counts()
# Out:
# 1     2361
# 2     2354
# 3     2350
# 6     2346
# 5     2341
# 4     2340
# 7     2339
# 8     2329
# 9     2305
# 10    2260
# 11    2186
# 12    2020
# 13     995
# 14     838
# Name: finishing_position, dtype: int64

# %%
rc=pd.DataFrame({"Race Count":merge_df["race_distance"].value_counts()})
rc
# Out:
#       Race Count
# 1200        9879
# 1400        5304
# 1650        4714
# 1000        2972
# 1600        2762
# 1800        2495
# 2000         697
# 2200         450
# 2400          93

# %%
rc.plot(kind="bar",color="red")
plt.title("Race graph")
plt.xlabel("Race distance")
plt.ylabel("Race Count")
plt.show()

# %%
trainer=pd.DataFrame({"Trainer":merge_df.groupby(["trainer","finishing_position"])["trainer"].count()})
trainer
# Out:
#                                    Trainer
# trainer        finishing_position
# A Bull         6                         1
# A Fabre        1                         1
#                2                         1
#                4                         1
#                7                         1
# ...                                    ...
# Y S Tsui       7                       132
#                8                       113
#                9                       112
# Y Yahagi       3                         1
# de Royer Dupre 3                         2
#
# [444 rows x 1 columns]
